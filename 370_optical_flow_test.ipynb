# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from types import SimpleNamespace
from main import main 


args = SimpleNamespace(
    input_vid_path='HOPS_370_100km_3_years_fits_pair.avi',
    output_dir='./video_out',
    output_fps=.5,
    threshold=253,
    scale=10,
    density=.05
)



position_storage_100, shift_storage_100 = main(args)
# Out:
# Processing frame number 2/6.0
# Processing frame number 3/6.0
# Processing frame number 4/6.0
# Processing frame number 5/6.0
# Processing frame number 6/6.0
# Finished
# 40 Velocities fitted

# %%
args = SimpleNamespace(
    input_vid_path='HOPS_370_75km_3_years_fits_pair.avi',
    output_dir='./video_out',
    output_fps=.5,
    threshold=253,
    scale=10,
    density=.05
)



position_storage_75, shift_storage_75 = main(args)
# Out:
# Processing frame number 2/6.0
# Processing frame number 3/6.0
# Processing frame number 4/6.0
# Processing frame number 5/6.0
# Processing frame number 6/6.0
# Finished
# 40 Velocities fitted

# %%
args = SimpleNamespace(
    input_vid_path='HOPS_370_50km_3_years_fits_pair.avi',
    output_dir='./video_out',
    output_fps=.5,
    threshold=253,
    scale=10,
    density=.05
)



position_storage_50, shift_storage_50 = main(args)
# Out:
# Processing frame number 2/6.0
# Processing frame number 3/6.0
# Processing frame number 4/6.0
# Processing frame number 5/6.0
# Processing frame number 6/6.0
# Finished
# 40 Velocities fitted

# %%
args = SimpleNamespace(
    input_vid_path='HOPS_370_25km_3_years_fits_pair.avi',
    output_dir='./video_out',
    output_fps=.5,
    threshold=253,
    scale=10,
    density=.05
)



position_storage_25, shift_storage_25 = main(args)
# Out:
# Processing frame number 2/6.0
# Processing frame number 3/6.0
# Processing frame number 4/6.0
# Processing frame number 5/6.0
# Processing frame number 6/6.0
# Finished
# 40 Velocities fitted

# %%
args = SimpleNamespace(
    input_vid_path='HOPS_370_15km_3_years_fits_pair.avi',
    output_dir='./video_out',
    output_fps=.5,
    threshold=253,
    scale=10,
    density=.05
)



position_storage_15, shift_storage_15 = main(args)
# Out:
# Processing frame number 2/6.0
# Processing frame number 3/6.0
# Processing frame number 4/6.0
# Processing frame number 5/6.0
# Processing frame number 6/6.0
# Finished
# 40 Velocities fitted

# %%
args = SimpleNamespace(
    input_vid_path='HOPS_370_5km_3_years_fits_pair.avi',
    output_dir='./video_out',
    output_fps=.5,
    threshold=253,
    scale=10,
    density=.05
)



position_storage_5, shift_storage_5 = main(args)
# Out:
# Processing frame number 2/6.0
# Processing frame number 3/6.0
# Processing frame number 4/6.0
# Processing frame number 5/6.0
# Processing frame number 6/6.0
# Finished
# 40 Velocities fitted

# %%
args = SimpleNamespace(
    input_vid_path='HOPS_370_1km_3_years_fits_pair.avi',
    output_dir='./video_out',
    output_fps=.5,
    threshold=253,
    scale=10,
    density=.05
)




position_storage_1, shift_storage_1 = main(args)
# Out:
# Processing frame number 2/6.0
# Processing frame number 3/6.0
# Processing frame number 4/6.0
# Processing frame number 5/6.0
# Processing frame number 6/6.0
# Finished
# 40 Velocities fitted

# %%
args = SimpleNamespace(
    input_vid_path='HOPS_370_dot_25km_3_years_fits_pair.avi',
    output_dir='./video_out',
    output_fps=.5,
    threshold=253,
    scale=10,
    density=.05
)



position_storage_dot_25, shift_storage_dot_25 = main(args)
# Out:
# Processing frame number 2/6.0
# Processing frame number 3/6.0
# Processing frame number 4/6.0
# Processing frame number 5/6.0
# Processing frame number 6/6.0
# Finished
# 40 Velocities fitted

# %%
args = SimpleNamespace(
    input_vid_path='HOPS_370_long_fits_pair.avi',
    output_dir='./video_out',
    output_fps=.5,
    threshold=100,
    scale=10,
    density=.05
)



position_storage_real, shift_storage_real = main(args)
# Out:
# Processing frame number 2/6.0
# Processing frame number 3/6.0
# Processing frame number 4/6.0
# Processing frame number 5/6.0
# Processing frame number 6/6.0
# Finished
# 366 Velocities fitted

# %%
# try a simulated offset

# %%
path_image_1 = "/home/wesley/Desktop/JWST_REU/Jorgensen_2024/"
path_image_2 = "/home/wesley/Desktop/JWST_REU/HEFE_2025/"

# %%
hdul_1 = fits.open((path_image_1 + 'HOPS_370_Jorgensen.fits'))
hdul_2 = fits.open((path_image_2 + 'HOPS_370_HEFE.fits'))
hdul_3 = fits.open((path_image_1 + 'sliced_nan_rm_Jorgensen_2024_f212n_pipeline.fits'))

# %%
velocity_pix_real = []
for k in range(len(shift_storage_real)):
    velcoity_calc = np.sqrt((shift_storage_real[k][0] **2) + (shift_storage_real[k][1] **2))
    velocity_pix_real.append(velcoity_calc)

# %%
velocity_real = []
for k in range(len(velocity_pix_real)):  
    velcoity_calc = (((((velocity_pix_real[k])*hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)/(86400*132)))
    # velcoity_calc = (((((velocity_pix_real[k])*hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)/(31536000*3)))

    velocity_real.append(velcoity_calc)

# %%
np.median(velocity_real)
# Out:
# np.float32(271.31787)

# %%
fig, ax = plt.subplots(1, 1,figsize=(20, 10))
plt.hist(velocity_real, bins=50)
plt.show()

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %% [markdown]
# # **Velocity Calculation**

# %%
velocity_pix_100 = []
for k in range(len(shift_storage_100)):
    velcoity_calc = np.sqrt((shift_storage_100[k][0] **2) + (shift_storage_100[k][1] **2))
    velocity_pix_100.append(velcoity_calc)

# %%
velocity_100 = []
for k in range(len(velocity_pix_100)):  
    # velcoity_calc = (((((velocity_pix[k])*hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)/(86400*132)))
    velcoity_calc = (((((velocity_pix_100[k])*hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)/(31536000*3)))

    velocity_100.append(velcoity_calc)

# %%
velocity_pix_75 = []
for k in range(len(shift_storage_75)):
    velcoity_calc = np.sqrt((shift_storage_75[k][0] **2) + (shift_storage_75[k][1] **2))
    velocity_pix_75.append(velcoity_calc)

# %%
velocity_75 = []
for k in range(len(velocity_pix_75)):  
    # velcoity_calc = (((((velocity_pix[k])*hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)/(86400*132)))
    velcoity_calc = (((((velocity_pix_75[k])*hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)/(31536000*3)))

    velocity_75.append(velcoity_calc)

# %%
velocity_pix_50 = []
for k in range(len(shift_storage_50)):
    velcoity_calc = np.sqrt((shift_storage_50[k][0] **2) + (shift_storage_50[k][1] **2))
    velocity_pix_50.append(velcoity_calc)

# %%
velocity_50 = []
for k in range(len(velocity_pix_50)):  
    # velcoity_calc = (((((velocity_pix[k])*hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)/(86400*132)))
    velcoity_calc = (((((velocity_pix_50[k])*hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)/(31536000*3)))

    velocity_50.append(velcoity_calc)

# %%
velocity_pix_25 = []
for k in range(len(shift_storage_25)):
    velcoity_calc = np.sqrt((shift_storage_25[k][0] **2) + (shift_storage_25[k][1] **2))
    velocity_pix_25.append(velcoity_calc)

# %%
velocity_25 = []
for k in range(len(velocity_pix_25)):  
    # velcoity_calc = (((((velocity_pix[k])*hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)/(86400*132)))
    velcoity_calc = (((((velocity_pix_25[k])*hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)/(31536000*3)))

    velocity_25.append(velcoity_calc)

# %%
velocity_pix_15 = []
for k in range(len(shift_storage_15)):
    velcoity_calc = np.sqrt((shift_storage_15[k][0] **2) + (shift_storage_15[k][1] **2))
    velocity_pix_15.append(velcoity_calc)

# %%
velocity_15 = []
for k in range(len(velocity_pix_15)):  
    # velcoity_calc = (((((velocity_pix[k])*hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)/(86400*132)))
    velcoity_calc = (((((velocity_pix_15[k])*hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)/(31536000*3)))

    velocity_15.append(velcoity_calc)

# %%
velocity_pix_5 = []
for k in range(len(shift_storage_5)):
    velcoity_calc = np.sqrt((shift_storage_5[k][0] **2) + (shift_storage_5[k][1] **2))
    velocity_pix_5.append(velcoity_calc)

# %%
velocity_5 = []
for k in range(len(velocity_pix_5)):  
    # velcoity_calc = (((((velocity_pix[k])*hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)/(86400*132)))
    velcoity_calc = (((((velocity_pix_5[k])*hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)/(31536000*3)))

    velocity_5.append(velcoity_calc)

# %%
velocity_pix_1 = []
for k in range(len(shift_storage_1)):
    velcoity_calc = np.sqrt((shift_storage_1[k][0] **2) + (shift_storage_1[k][1] **2))
    velocity_pix_1.append(velcoity_calc)

# %%
velocity_1 = []
for k in range(len(velocity_pix_1)):  
    # velcoity_calc = (((((velocity_pix[k])*hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)/(86400*132)))
    velcoity_calc = (((((velocity_pix_1[k])*hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)/(31536000*3)))

    velocity_1.append(velcoity_calc)

# %%
velocity_pix_dot_25 = []
for k in range(len(shift_storage_dot_25)):
    velcoity_calc = np.sqrt((shift_storage_dot_25[k][0] **2) + (shift_storage_dot_25[k][1] **2))
    velocity_pix_dot_25.append(velcoity_calc)

# %%
velocity_dot_25 = []
for k in range(len(velocity_pix_dot_25)):  
    # velcoity_calc = (((((velocity_pix[k])*hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)/(86400*132)))
    velcoity_calc = (((((velocity_pix_dot_25[k])*hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)/(31536000*3)))

    velocity_dot_25.append(velcoity_calc)

# %%
(.25 * (31536000*3)) / ((hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)
# Out:
# 0.012889067485091032

# %%
(((((0.25778134970182065)*hdul_3[1].header["CDELT1"])*3600*392.8*149597870.69)/(86400*132)))
# Out:
# 41.47727272727272

# %%
# around 0.77 pixel shift for actual measuremts

# %% [markdown]
# # **Results**

# %%
std_of_mean = np.std(velocity_100)/ np.sqrt(len(velocity_100))
print('************ Jorgensen 2024 ************')
print ('Velocity (km s-1) (Actual = 100 km s-1)', np.mean(velocity_100))
print ('Percent Deviation', (100 - np.mean(velocity_100)) / 100)
print ('Standard deviation (km s-1)', np.std(velocity_100))
print ('Standard deviation of the mean (km s-1)', std_of_mean)
# Out:
# ************ Jorgensen 2024 ************
# Velocity (km s-1) (Actual = 100 km s-1) 100.03048
# Percent Deviation -0.00030479432
# Standard deviation (km s-1) 1.4549295
# Standard deviation of the mean (km s-1) 0.23004454816571365

# %%
std_of_mean = np.std(velocity_75)/ np.sqrt(len(velocity_75))
print('************ Jorgensen 2024 ************')
print ('Velocity (km s-1) (Actual = 75 km s-1)', np.mean(velocity_75))
print ('Percent Deviation', (75 - np.mean(velocity_75)) / 75)
print ('Standard deviation (km s-1)', np.std(velocity_75))
print ('Standard deviation of the mean (km s-1)', std_of_mean)
# Out:
# ************ Jorgensen 2024 ************
# Velocity (km s-1) (Actual = 75 km s-1) 74.59785
# Percent Deviation 0.0053620404
# Standard deviation (km s-1) 0.9961423
# Standard deviation of the mean (km s-1) 0.1575039314752094

# %%
std_of_mean = np.std(velocity_50)/ np.sqrt(len(velocity_50))
print('************ Jorgensen 2024 ************')
print ('Velocity (km s-1) (Actual = 50 km s-1)', np.mean(velocity_50))
print ('Percent Deviation', (50 - np.mean(velocity_50)) / 50)
print ('Standard deviation (km s-1)', np.std(velocity_50))
print ('Standard deviation of the mean (km s-1)', std_of_mean)
# Out:
# ************ Jorgensen 2024 ************
# Velocity (km s-1) (Actual = 50 km s-1) 49.898216
# Percent Deviation 0.002035675
# Standard deviation (km s-1) 1.6968536
# Standard deviation of the mean (km s-1) 0.2682961175529668

# %%
std_of_mean = np.std(velocity_25)/ np.sqrt(len(velocity_25))
print('************ Jorgensen 2024 ************')
print ('Velocity (km s-1) (Actual = 25 km s-1)', np.mean(velocity_25))
print ('Percent Deviation', (25 - np.mean(velocity_25)) / 25 * 100)
print ('Standard deviation (km s-1)', np.std(velocity_25))
print ('Standard deviation of the mean (km s-1)', std_of_mean)
# Out:
# ************ Jorgensen 2024 ************
# Velocity (km s-1) (Actual = 25 km s-1) 25.275202
# Percent Deviation -1.1008072
# Standard deviation (km s-1) 1.7806299
# Standard deviation of the mean (km s-1) 0.2815423034644189

# %%
std_of_mean = np.std(velocity_15)/ np.sqrt(len(velocity_15))
print('************ Jorgensen 2024 ************')
print ('Velocity (km s-1) (Actual = 15 km s-1)', np.mean(velocity_15))
print ('Percent Deviation', (15 - np.mean(velocity_15)) / 15 * 100)
print ('Standard deviation (km s-1)', np.std(velocity_15))
print ('Standard deviation of the mean (km s-1)', std_of_mean)
# Out:
# ************ Jorgensen 2024 ************
# Velocity (km s-1) (Actual = 15 km s-1) 15.025543
# Percent Deviation -0.17028809
# Standard deviation (km s-1) 1.3001195
# Standard deviation of the mean (km s-1) 0.2055669455610797

# %%
std_of_mean = np.std(velocity_5)/ np.sqrt(len(velocity_5))
print('************ Jorgensen 2024 ************')
print ('Velocity (km s-1) (Actual = 5 km s-1)', np.mean(velocity_5))
print ('Percent Deviation', (5 - np.mean(velocity_5)) / 5 * 100)
print ('Standard deviation (km s-1)', np.std(velocity_5))
print ('Standard deviation of the mean (km s-1)', std_of_mean)
# Out:
# ************ Jorgensen 2024 ************
# Velocity (km s-1) (Actual = 5 km s-1) 5.4370146
# Percent Deviation -8.740292
# Standard deviation (km s-1) 1.951527
# Standard deviation of the mean (km s-1) 0.3085635116825352

# %%
std_of_mean = np.std(velocity_1)/ np.sqrt(len(velocity_1))
print('************ Jorgensen 2024 ************')
print ('Velocity (km s-1) (Actual = 1 km s-1)', np.mean(velocity_1))
print ('Percent Deviation', (1 - np.mean(velocity_1)) / 1 * 100)
print ('Standard deviation (km s-1)', np.std(velocity_1))
print ('Standard deviation of the mean (km s-1)', std_of_mean)
# Out:
# ************ Jorgensen 2024 ************
# Velocity (km s-1) (Actual = 1 km s-1) 1.6577902
# Percent Deviation -65.77902
# Standard deviation (km s-1) 1.0729843
# Standard deviation of the mean (km s-1) 0.16965372005783472

# %%
std_of_mean = np.std(velocity_dot_25)/ np.sqrt(len(velocity_dot_25))
print('************ Jorgensen 2024 ************')
print ('Velocity (km s-1) (Actual = 50 km s-1)', np.mean(velocity_dot_25))
print ('Percent Deviation', (.25 - np.mean(velocity_dot_25))/.25 * 100)
print ('Standard deviation (km s-1)', np.std(velocity_dot_25))
print ('Standard deviation of the mean (km s-1)', std_of_mean)
# Out:
# ************ Jorgensen 2024 ************
# Velocity (km s-1) (Actual = 50 km s-1) 0.9194149
# Percent Deviation -267.76596
# Standard deviation (km s-1) 0.57175076
# Standard deviation of the mean (km s-1) 0.09040173278901552

# %% [markdown]
# # **Graphs**

# %%
fig, ax = plt.subplots(1, 1,figsize=(20, 10))
ax.scatter(np.ones(len(velocity_100)) * 100, np.abs(100 - np.array(velocity_100)) / 100 * 100)
ax.scatter(np.ones(len(velocity_75)) * 75, np.abs(75 - np.array(velocity_75)) / 75 * 100)
ax.scatter(np.ones(len(velocity_50)) * 50, np.abs(50 - np.array(velocity_50)) / 50 * 100)
ax.scatter(np.ones(len(velocity_25)) * 25, np.abs(25 - np.array(velocity_25)) / 25 * 100)
ax.scatter(np.ones(len(velocity_15)) * 15, np.abs(15 - np.array(velocity_15)) / 15 * 100)
ax.scatter(np.ones(len(velocity_5)) * 5, np.abs(5 - np.array(velocity_5)) / 5 * 100)
ax.scatter(np.ones(len(velocity_1)) * 1, np.abs(1 - np.array(velocity_1)) / 1 * 100)
ax.scatter(np.ones(len(velocity_dot_25)) * .25, np.abs(.25 - np.array(velocity_dot_25)) /.25 * 100)
plt.axhline(y=5, color='red', linestyle='-', linewidth=2)

x= np.linspace(0,100, num=1000)
k = 3
y = k / x *100
ax.plot(x,y)

ax.set_ylim([0, 20])
# ax.set_ylim([0, 1200])
plt.rc('font', size=20)
plt.show()
# Out:
# /tmp/ipykernel_70930/3078559100.py:14: RuntimeWarning: divide by zero encountered in divide
#   y = k / x *100
